# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ches_results = pd.read_excel('../data/ches_scores/LLM scores vs CHES.xlsx')[['Document','Status','Dimension','Expert mean']]

# %%
ches_results = ches_results[~ches_results['Status'].isna()]

# %%
ches_results
# Out:
#              Document       Status        Dimension Expert mean
# 1       CZ 2006 Green  Calibration               EU        6.25
# 2       CZ 2006 Green  Calibration         TaxSpend        5.67
# 3       CZ 2006 Green  Calibration  SocialLifestyle           3
# 4       CZ 2006 Green  Calibration      Immigration        4.75
# 5       CZ 2006 Green  Calibration      Environment           x
# ..                ...          ...              ...         ...
# 69  SWE 2010 Moderate         Test         TaxSpend        7.57
# 70  SWE 2010 Moderate         Test  SocialLifestyle        3.21
# 71  SWE 2010 Moderate         Test      Immigration        5.36
# 72  SWE 2010 Moderate         Test      Environment        5.93
# 73  SWE 2010 Moderate         Test          Regions        5.17
#
# [72 rows x 4 columns]

# %%
llm_results = pd.read_excel('../data/results/test_set_results.xlsx')

# %%
llm_results
# Out:
#                                                   file             issue  \
# 0       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 1       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 2       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 3       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 4       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# ...                                                ...               ...
# 1291  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1292  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1293  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1294  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1295  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
#
#                            model  score  error_message  \
# 0                         gpt-4o    6.0            NaN
# 1                         gpt-4o    6.0            NaN
# 2                         gpt-4o    6.0            NaN
# 3                         gpt-4o    6.0            NaN
# 4                         gpt-4o    6.0            NaN
# ...                          ...    ...            ...
# 1291  claude-3-5-sonnet-20240620    3.0            NaN
# 1292  claude-3-5-sonnet-20240620    3.0            NaN
# 1293  claude-3-5-sonnet-20240620    3.0            NaN
# 1294  claude-3-5-sonnet-20240620    3.0            NaN
# 1295  claude-3-5-sonnet-20240620    3.0            NaN
#
#                                                  prompt  \
# 0     [SystemMessage(content='\n    You are an exper...
# 1     [SystemMessage(content='\n    You are an exper...
# 2     [SystemMessage(content='\n    You are an exper...
# 3     [SystemMessage(content='\n    You are highly i...
# 4     [SystemMessage(content='\n    You are highly i...
# ...                                                 ...
# 1291  [SystemMessage(content='\n    You are highly i...
# 1292  [SystemMessage(content='\n    You are highly i...
# 1293  [SystemMessage(content='\n    You are a profes...
# 1294  [SystemMessage(content='\n    You are a profes...
# 1295  [SystemMessage(content='\n    You are a profes...
#
#                   created_at
# 0    2024-06-30 07:38:53.136
# 1    2024-06-30 07:38:53.136
# 2    2024-06-30 07:38:53.136
# 3    2024-06-30 07:38:53.136
# 4    2024-06-30 07:38:53.136
# ...                      ...
# 1291 2024-06-30 07:58:27.080
# 1292 2024-06-30 07:58:27.080
# 1293 2024-06-30 07:58:27.080
# 1294 2024-06-30 07:58:27.080
# 1295 2024-06-30 07:58:27.080
#
# [1296 rows x 7 columns]

# %%
issue_map = {'european_union': 'EU',
             'taxation': 'TaxSpend',
             'lifestyle': 'SocialLifestyle',
             'immigration': 'Immigration',
             'environment': 'Environment',
             'decentralization': 'Regions'}

# %%
llm_results['ches_issue'] = llm_results['issue'].map(issue_map)

# %%
llm_results
# Out:
#                                                   file             issue  \
# 0       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 1       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 2       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 3       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 4       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# ...                                                ...               ...
# 1291  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1292  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1293  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1294  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1295  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
#
#                            model  score  error_message  \
# 0                         gpt-4o    6.0            NaN
# 1                         gpt-4o    6.0            NaN
# 2                         gpt-4o    6.0            NaN
# 3                         gpt-4o    6.0            NaN
# 4                         gpt-4o    6.0            NaN
# ...                          ...    ...            ...
# 1291  claude-3-5-sonnet-20240620    3.0            NaN
# 1292  claude-3-5-sonnet-20240620    3.0            NaN
# 1293  claude-3-5-sonnet-20240620    3.0            NaN
# 1294  claude-3-5-sonnet-20240620    3.0            NaN
# 1295  claude-3-5-sonnet-20240620    3.0            NaN
#
#                                                  prompt  \
# 0     [SystemMessage(content='\n    You are an exper...
# 1     [SystemMessage(content='\n    You are an exper...
# 2     [SystemMessage(content='\n    You are an exper...
# 3     [SystemMessage(content='\n    You are highly i...
# 4     [SystemMessage(content='\n    You are highly i...
# ...                                                 ...
# 1291  [SystemMessage(content='\n    You are highly i...
# 1292  [SystemMessage(content='\n    You are highly i...
# 1293  [SystemMessage(content='\n    You are a profes...
# 1294  [SystemMessage(content='\n    You are a profes...
# 1295  [SystemMessage(content='\n    You are a profes...
#
#                   created_at ches_issue
# 0    2024-06-30 07:38:53.136         EU
# 1    2024-06-30 07:38:53.136         EU
# 2    2024-06-30 07:38:53.136         EU
# 3    2024-06-30 07:38:53.136         EU
# 4    2024-06-30 07:38:53.136         EU
# ...                      ...        ...
# 1291 2024-06-30 07:58:27.080    Regions
# 1292 2024-06-30 07:58:27.080    Regions
# 1293 2024-06-30 07:58:27.080    Regions
# 1294 2024-06-30 07:58:27.080    Regions
# 1295 2024-06-30 07:58:27.080    Regions
#
# [1296 rows x 8 columns]

# %%
llm_results['ches_file'] = llm_results.file.apply(lambda x: x.split('/')[-1].split('-')[-1].split('.')[0].strip())

# %%
llm_results['ches_file']
# Out:
# 0         POR1999 Soc Dem
# 1         POR1999 Soc Dem
# 2         POR1999 Soc Dem
# 3         POR1999 Soc Dem
# 4         POR1999 Soc Dem
#               ...
# 1291    SWE 2010 Moderate
# 1292    SWE 2010 Moderate
# 1293    SWE 2010 Moderate
# 1294    SWE 2010 Moderate
# 1295    SWE 2010 Moderate
# Name: ches_file, Length: 1296, dtype: object

# %%
merged_results = llm_results.merge(ches_results[['Document', 'Dimension', 'Expert mean']], left_on=['ches_file','ches_issue'], right_on=['Document', 'Dimension'], how='left', copy=False)

# %%
merged_results
# Out:
#                                                   file             issue  \
# 0       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 1       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 2       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 3       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# 4       ../data/plaintext/1 Test - POR1999 Soc Dem.txt    european_union
# ...                                                ...               ...
# 1291  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1292  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1293  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1294  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
# 1295  ../data/plaintext/1 Test - SWE 2010 Moderate.txt  decentralization
#
#                            model  score  error_message  \
# 0                         gpt-4o    6.0            NaN
# 1                         gpt-4o    6.0            NaN
# 2                         gpt-4o    6.0            NaN
# 3                         gpt-4o    6.0            NaN
# 4                         gpt-4o    6.0            NaN
# ...                          ...    ...            ...
# 1291  claude-3-5-sonnet-20240620    3.0            NaN
# 1292  claude-3-5-sonnet-20240620    3.0            NaN
# 1293  claude-3-5-sonnet-20240620    3.0            NaN
# 1294  claude-3-5-sonnet-20240620    3.0            NaN
# 1295  claude-3-5-sonnet-20240620    3.0            NaN
#
#                                                  prompt  \
# 0     [SystemMessage(content='\n    You are an exper...
# 1     [SystemMessage(content='\n    You are an exper...
# 2     [SystemMessage(content='\n    You are an exper...
# 3     [SystemMessage(content='\n    You are highly i...
# 4     [SystemMessage(content='\n    You are highly i...
# ...                                                 ...
# 1291  [SystemMessage(content='\n    You are highly i...
# 1292  [SystemMessage(content='\n    You are highly i...
# 1293  [SystemMessage(content='\n    You are a profes...
# 1294  [SystemMessage(content='\n    You are a profes...
# 1295  [SystemMessage(content='\n    You are a profes...
#
#                   created_at ches_issue          ches_file           Document  \
# 0    2024-06-30 07:38:53.136         EU    POR1999 Soc Dem                NaN
# 1    2024-06-30 07:38:53.136         EU    POR1999 Soc Dem                NaN
# 2    2024-06-30 07:38:53.136         EU    POR1999 Soc Dem                NaN
# 3    2024-06-30 07:38:53.136         EU    POR1999 Soc Dem                NaN
# 4    2024-06-30 07:38:53.136         EU    POR1999 Soc Dem                NaN
# ...                      ...        ...                ...                ...
# 1291 2024-06-30 07:58:27.080    Regions  SWE 2010 Moderate  SWE 2010 Moderate
# 1292 2024-06-30 07:58:27.080    Regions  SWE 2010 Moderate  SWE 2010 Moderate
# 1293 2024-06-30 07:58:27.080    Regions  SWE 2010 Moderate  SWE 2010 Moderate
# 1294 2024-06-30 07:58:27.080    Regions  SWE 2010 Moderate  SWE 2010 Moderate
# 1295 2024-06-30 07:58:27.080    Regions  SWE 2010 Moderate  SWE 2010 Moderate
#
#      Dimension Expert mean
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# ...        ...         ...
# 1291   Regions        5.17
# 1292   Regions        5.17
# 1293   Regions        5.17
# 1294   Regions        5.17
# 1295   Regions        5.17
#
# [1296 rows x 12 columns]

# %%
merged_results[merged_results['Expert mean'].isna()].ches_file.value_counts()
# Out:
# ches_file
# POR1999 Soc Dem    162
# FR 2002 FN txt     162
# Name: count, dtype: int64

# %%
cleaned_results = merged_results[~merged_results['Expert mean'].isna()]

# %%
cleaned_results = cleaned_results.drop(columns=['Document', 'Dimension', 'file','issue','error_message','created_at'])

# %%
cleaned_results
# Out:
#                            model  score  \
# 162                       gpt-4o    1.0
# 163                       gpt-4o    1.0
# 164                       gpt-4o    1.0
# 165                       gpt-4o    1.0
# 166                       gpt-4o    1.0
# ...                          ...    ...
# 1291  claude-3-5-sonnet-20240620    3.0
# 1292  claude-3-5-sonnet-20240620    3.0
# 1293  claude-3-5-sonnet-20240620    3.0
# 1294  claude-3-5-sonnet-20240620    3.0
# 1295  claude-3-5-sonnet-20240620    3.0
#
#                                                  prompt ches_issue  \
# 162   [SystemMessage(content='\n    You are an exper...         EU
# 163   [SystemMessage(content='\n    You are an exper...         EU
# 164   [SystemMessage(content='\n    You are an exper...         EU
# 165   [SystemMessage(content='\n    You are highly i...         EU
# 166   [SystemMessage(content='\n    You are highly i...         EU
# ...                                                 ...        ...
# 1291  [SystemMessage(content='\n    You are highly i...    Regions
# 1292  [SystemMessage(content='\n    You are highly i...    Regions
# 1293  [SystemMessage(content='\n    You are a profes...    Regions
# 1294  [SystemMessage(content='\n    You are a profes...    Regions
# 1295  [SystemMessage(content='\n    You are a profes...    Regions
#
#               ches_file Expert mean
# 162     BUL 2014 Attack         1.5
# 163     BUL 2014 Attack         1.5
# 164     BUL 2014 Attack         1.5
# 165     BUL 2014 Attack         1.5
# 166     BUL 2014 Attack         1.5
# ...                 ...         ...
# 1291  SWE 2010 Moderate        5.17
# 1292  SWE 2010 Moderate        5.17
# 1293  SWE 2010 Moderate        5.17
# 1294  SWE 2010 Moderate        5.17
# 1295  SWE 2010 Moderate        5.17
#
# [972 rows x 6 columns]

# %%
cleaned_results['difference'] = pd.to_numeric(cleaned_results['score'], errors='coerce') - pd.to_numeric(cleaned_results['Expert mean'], errors='coerce')

# %% [markdown]
# ### Trimming out the ones claude couldn't finish

# %%
cleaned_results = cleaned_results[cleaned_results.ches_file != 'SWE 2010 Moderate']

# %%
cleaned_results['difference'].hist()
# Out:
# <Axes: >

# %%
sns.set_theme(style="whitegrid")

# %%
# 1. Histogram of 'difference'
plt.figure(figsize=(10, 6))
sns.histplot(cleaned_results['difference'], bins=10, kde=True)
plt.title('Histogram of Difference - All Issues - Few Shot (LLM - CHES)')
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.axvline(x=0, linestyle='--', color='red')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=cleaned_results, x='difference', hue='ches_issue', fill=True)
plt.title('Kernel Density Plot of Difference (LLM - Ches) - Few Shot by Issue')
plt.xlabel('Difference')
plt.ylabel('Density')
plt.axvline(x=0, linestyle='--', color='red')
plt.show()

# %%
# Create the FacetGrid
g = sns.FacetGrid(cleaned_results, col="ches_issue", col_wrap=3, height=4, sharex=True, sharey=True)

# Map the kdeplot to each facet
g.map(sns.kdeplot, "difference", fill=True)

# Add titles and adjust the layout
g.set_titles("{col_name}")
g.set_axis_labels("Difference", "Density")
plt.subplots_adjust(top=0.9)
g.figure.suptitle('Kernel Density Plot of Difference (LLM - Ches) - Few Shot by Issue')
g.map(plt.axvline, x=0, linestyle='--', color='red')

# Show the plot
plt.show()

# %%
cleaned_results.model = cleaned_results.model.map({'gemini-1.5-pro-001': 'Gemini 1.5 Pro',
                           'claude-3-5-sonnet-20240620': 'Claude 3.5 Sonnet',
                           'gpt-4o': 'GPT-4o',})
# Out:
# /var/folders/60/fmd_xz955yjg04drm96_8h540000gn/T/ipykernel_85187/2494363582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_results.model = cleaned_results.model.map({'gemini-1.5-pro-001': 'Gemini 1.5 Pro',

# %%
cleaned_results.model.value_counts()
# Out:
# model
# GPT-4o               270
# Gemini 1.5 Pro       270
# Claude 3.5 Sonnet    270
# Name: count, dtype: int64

# %%
g = sns.FacetGrid(cleaned_results, col="ches_issue", hue="model", col_wrap=3, height=4, sharex=True, sharey=True)

# Map the kdeplot to each facet
g.map(sns.kdeplot, "difference", fill=True)

# Add a vertical line at 0 to each facet
for ax in g.axes.flat:
    ax.axvline(x=0, linestyle='--', color='red')

# Add titles and adjust the layout
g.set_titles("{col_name}")
g.set_axis_labels("Difference", "Density")
plt.subplots_adjust(top=0.9)
g.figure.suptitle('Zero Shot - Kernel Density Plot of Difference (LLM - Ches) by Ches Issue and Model')

# Add legend
g.add_legend()

g.set(xlim=(-9, 7))
g.set(ylim=(0, 0.5))

# Show the plot
plt.show()

# %%
cleaned_results.to_excel('../data/results/ches_comparison_results.xlsx', index=False)
