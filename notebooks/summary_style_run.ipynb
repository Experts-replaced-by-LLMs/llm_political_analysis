# %%
import os
from datetime import datetime

import pandas as pd

from llm_political_analysis.modules.summarize import summarize_file
from llm_political_analysis.modules.prompts import get_prompts
from llm_political_analysis.modules.analyze import analyze_text_with_batch

# %%
test_files = os.listdir('../data/plaintext/new_test')
calibration_files = os.listdir('../data/plaintext/new_calibration')

# %%
file_list =  ['../data/plaintext/new_calibration/'+file for file in calibration_files] + ['../data/plaintext/new_test/'+file for file in test_files]
file_list
# Out:
# ['../data/plaintext/new_calibration/Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  '../data/plaintext/new_calibration/Austria - AU 2019 - AU 2019 SDP.txt',
#  '../data/plaintext/new_calibration/Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  '../data/plaintext/new_calibration/Poland - POL 2019 Civic Coalition PO.txt',
#  '../data/plaintext/new_calibration/Denmark - DEN 2019 SPP SF.txt',
#  '../data/plaintext/new_calibration/Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  '../data/plaintext/new_calibration/Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  '../data/plaintext/new_calibration/Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  '../data/plaintext/new_test/UK - UK 2019 Green.txt',
#  '../data/plaintext/new_test/Netherlands - NL 2006 - NL 2006 VVD.txt',
#  '../data/plaintext/new_test/Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  '../data/plaintext/new_test/Slovakia - SLO 2006 - SLO 2006 Direction.txt',
#  '../data/plaintext/new_test/Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  '../data/plaintext/new_test/Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  '../data/plaintext/new_test/Bulgaria - BUL 2014 Attack.txt',
#  '../data/plaintext/new_test/Austria - AU 2006 - AU 2006 FPO.txt']

# %%
summary_lengths = [1000, 2000]
model = 'gpt-4o'
output_dir = '../data/summaries/'
issue_list = ['european_union', 'taxation', 'lifestyle', 'immigration', 'environment', 'decentralization']
results_file = '../data/results/standard_length_summary_results.xlsx'

# %%
overall_results = []
summary_length = 1000
# Loop through each file, issue area
for file_name in file_list:
    print('Analyzing file: ', file_name)
    all_issue_summary = summarize_file(file_name, issue_list, output_dir, save_summary=True, if_exists='reuse')

    for issue in issue_list:
        print('-- Analyzing issue: ', issue)
        issue_specific_summary = summarize_file(file_name, [issue], output_dir, save_summary=True, if_exists='reuse')
        
        print('---- Analyzing with all issue summaries ')
        all_issue_prompts = get_prompts(issue, all_issue_summary, override_persona_and_encouragement=(0,1))
        all_issue_prompts_results = analyze_text_with_batch(all_issue_prompts, model, parse_retries=3, max_retries=7, concurrency=9)
        all_issue_prompts_results_df = pd.DataFrame(all_issue_prompts_results)
        all_issue_prompts_results_df['summary_style'] = 'all_issues'

        print('---- Analyzing with issue specific summaries ')
        issue_specific_prompts = get_prompts(issue, issue_specific_summary, override_persona_and_encouragement=(0,1))
        issue_specific_prompts_results = analyze_text_with_batch(issue_specific_prompts, model, parse_retries=3, max_retries=7, concurrency=9)
        issue_specific_prompts_results_df = pd.DataFrame(issue_specific_prompts_results)
        issue_specific_prompts_results_df['summary_style'] = 'issue_specific'

        results_df = pd.concat([all_issue_prompts_results_df, issue_specific_prompts_results_df], axis=0)
        results_df['summary_length'] = summary_length
        results_df['issue'] = issue
        results_df['model'] = model
        results_df['file'] = file_name
        results_df['created_at'] = datetime.now()
        results_df = results_df[[
            'file', 'issue', 'model', 'summary_style', 'summary_length', 'score', 'error_message', 'prompt', 'created_at']]

        # Writing to Excel as we go to avoid losing data in case of an error
        if os.path.exists(results_file):
            # Append to existing file
            with pd.ExcelWriter(results_file, mode='a', engine='openpyxl', if_sheet_exists='overlay') as writer:
                results_df.to_excel(
                    writer, index=False, header=False, sheet_name='Sheet1', startrow=writer.sheets['Sheet1'].max_row)
        else:
            # Create a new file
            with pd.ExcelWriter(results_file, mode='w', engine='openpyxl') as writer:
                results_df.to_excel(
                    writer, index=False, sheet_name='Sheet1')

        overall_results.append(results_df)

final_df = pd.concat(overall_results, axis=0)
final_df = final_df.reset_index(drop=True)
# Out:
# Analyzing file:  ../data/plaintext/new_test/Bulgaria - BUL 2014 Attack.txt
# Summary file ../data/summaries/summary_standard_multi_issue__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# -- Analyzing issue:  european_union
# Summary file ../data/summaries/summary_standard_european_union__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# ---- Analyzing with all issue summaries
# ---- Analyzing with issue specific summaries
# -- Analyzing issue:  taxation
# Summary file ../data/summaries/summary_standard_taxation__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# ---- Analyzing with all issue summaries
# ---- Analyzing with issue specific summaries
# -- Analyzing issue:  lifestyle
# Summary file ../data/summaries/summary_standard_lifestyle__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# ---- Analyzing with all issue summaries
# ---- Analyzing with issue specific summaries
# -- Analyzing issue:  immigration
# Summary file ../data/summaries/summary_standard_immigration__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# ---- Analyzing with all issue summaries
# ---- Analyzing with issue specific summaries
# -- Analyzing issue:  environment
# Summary file ../data/summaries/summary_standard_environment__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# ---- Analyzing with all issue summaries
# ---- Analyzing with issue specific summaries
# -- Analyzing issue:  decentralization
# Summary file ../data/summaries/summary_standard_decentralization__Bulgaria - BUL 2014 Attack.txt already exists. Reusing the existing summary.
# ---- Analyzing with all issue summaries
# ---- Analyzing with issue specific summaries

# %%
final_df
# Out:
#                                                  file             issue  \
# 0   ../data/plaintext/new_test/Bulgaria - BUL 2014...    european_union
# 1   ../data/plaintext/new_test/Bulgaria - BUL 2014...    european_union
# 2   ../data/plaintext/new_test/Bulgaria - BUL 2014...          taxation
# 3   ../data/plaintext/new_test/Bulgaria - BUL 2014...          taxation
# 4   ../data/plaintext/new_test/Bulgaria - BUL 2014...         lifestyle
# 5   ../data/plaintext/new_test/Bulgaria - BUL 2014...         lifestyle
# 6   ../data/plaintext/new_test/Bulgaria - BUL 2014...       immigration
# 7   ../data/plaintext/new_test/Bulgaria - BUL 2014...       immigration
# 8   ../data/plaintext/new_test/Bulgaria - BUL 2014...       environment
# 9   ../data/plaintext/new_test/Bulgaria - BUL 2014...       environment
# 10  ../data/plaintext/new_test/Bulgaria - BUL 2014...  decentralization
# 11  ../data/plaintext/new_test/Bulgaria - BUL 2014...  decentralization
#
#      model   summary_style  summary_length score error_message  \
# 0   gpt-4o      all_issues            1000     7          None
# 1   gpt-4o  issue_specific            1000     7          None
# 2   gpt-4o      all_issues            1000     2          None
# 3   gpt-4o  issue_specific            1000     1          None
# 4   gpt-4o      all_issues            1000    NA          None
# 5   gpt-4o  issue_specific            1000    NA          None
# 6   gpt-4o      all_issues            1000    NA          None
# 7   gpt-4o  issue_specific            1000     7          None
# 8   gpt-4o      all_issues            1000     7          None
# 9   gpt-4o  issue_specific            1000     7          None
# 10  gpt-4o      all_issues            1000    NA          None
# 11  gpt-4o  issue_specific            1000     7          None
#
#                                                prompt  \
# 0   [content="You are an expert social scientist w...
# 1   [content="You are an expert social scientist w...
# 2   [content='You are an expert social scientist w...
# 3   [content='You are an expert social scientist w...
# 4   [content='You are an expert social scientist w...
# 5   [content='You are an expert social scientist w...
# 6   [content='You are an expert social scientist w...
# 7   [content='You are an expert social scientist w...
# 8   [content='You are an expert social scientist w...
# 9   [content='You are an expert social scientist w...
# 10  [content='You are an expert social scientist w...
# 11  [content='You are an expert social scientist w...
#
#                    created_at
# 0  2024-07-31 20:14:45.350280
# 1  2024-07-31 20:14:45.350280
# 2  2024-07-31 20:14:46.469480
# 3  2024-07-31 20:14:46.469480
# 4  2024-07-31 20:14:47.629853
# 5  2024-07-31 20:14:47.629853
# 6  2024-07-31 20:14:49.369207
# 7  2024-07-31 20:14:49.369207
# 8  2024-07-31 20:14:50.293716
# 9  2024-07-31 20:14:50.293716
# 10 2024-07-31 20:14:51.723986
# 11 2024-07-31 20:14:51.723986

# %% [markdown]
# ### We can simulate a long summary by combining the single issue summaries into one doc

# %% [markdown]
# First lets grab the single issue summaries

# %%
single_summaries = [file for file in os.listdir('../data/summaries/') if (file.startswith('summary_standard') and not 'multi_issue' in file)]

# %%
single_summaries
# Out:
# ['summary_standard_immigration__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  'summary_standard_european_union__Poland - POL 2019 Civic Coalition PO.txt',
#  'summary_standard_taxation__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  'summary_standard_environment__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  'summary_standard_european_union__Austria - AU 2006 - AU 2006 FPO.txt',
#  'summary_standard_immigration__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  'summary_standard_environment__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  'summary_standard_decentralization__Austria - AU 2006 - AU 2006 FPO.txt',
#  'summary_standard_environment__Austria - AU 2019 - AU 2019 SDP.txt',
#  'summary_standard_decentralization__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  'summary_standard_taxation__Austria - AU 2019 - AU 2019 SDP.txt',
#  'summary_standard_taxation__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  'summary_standard_environment__Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  'summary_standard_taxation__Bulgaria - BUL 2014 Attack.txt',
#  'summary_standard_lifestyle__UK - UK 2019 Green.txt',
#  'summary_standard_environment__Poland - POL 2019 Civic Coalition PO.txt',
#  'summary_standard_lifestyle__Denmark - DEN 2019 SPP SF.txt',
#  'summary_standard_immigration__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  'summary_standard_immigration__Bulgaria - BUL 2014 Attack.txt',
#  'summary_standard_immigration__Poland - POL 2019 Civic Coalition PO.txt',
#  'summary_standard_european_union__Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  'summary_standard_decentralization__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  'summary_standard_taxation__Slovakia - SLO 2006 - SLO 2006 Direction.txt',
#  'summary_standard_immigration__Austria - AU 2019 - AU 2019 SDP.txt',
#  'summary_standard_taxation__Poland - POL 2019 Civic Coalition PO.txt',
#  'summary_standard_lifestyle__Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  'summary_standard_environment__Netherlands - NL 2006 - NL 2006 VVD.txt',
#  'summary_standard_lifestyle__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  'summary_standard_decentralization__Netherlands - NL 2006 - NL 2006 VVD.txt',
#  'summary_standard_taxation__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  'summary_standard_taxation__Netherlands - NL 2006 - NL 2006 VVD.txt',
#  'summary_standard_decentralization__Denmark - DEN 2019 SPP SF.txt',
#  'summary_standard_european_union__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  'summary_standard_taxation__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  'summary_standard_taxation__Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  'summary_standard_lifestyle__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  'summary_standard_decentralization__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  'summary_standard_environment__UK - UK 2019 Green.txt',
#  'summary_standard_lifestyle__Slovakia - SLO 2006 - SLO 2006 Direction.txt',
#  'summary_standard_lifestyle__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  'summary_standard_european_union__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  'summary_standard_environment__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  'summary_standard_decentralization__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  'summary_standard_lifestyle__Austria - AU 2006 - AU 2006 FPO.txt',
#  'summary_standard_european_union__Netherlands - NL 2006 - NL 2006 VVD.txt',
#  'summary_standard_taxation__Denmark - DEN 2019 SPP SF.txt',
#  'summary_standard_decentralization__UK - UK 2019 Green.txt',
#  'summary_standard_decentralization__Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  'summary_standard_environment__Bulgaria - BUL 2014 Attack.txt',
#  'summary_standard_decentralization__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  'summary_standard_taxation__UK - UK 2019 Green.txt',
#  'summary_standard_decentralization__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  'summary_standard_decentralization__Bulgaria - BUL 2014 Attack.txt',
#  'summary_standard_immigration__Austria - AU 2006 - AU 2006 FPO.txt',
#  'summary_standard_european_union__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  'summary_standard_decentralization__Poland - POL 2019 Civic Coalition PO.txt',
#  'summary_standard_lifestyle__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  'summary_standard_lifestyle__Netherlands - NL 2006 - NL 2006 VVD.txt',
#  'summary_standard_european_union__Bulgaria - BUL 2014 Attack.txt',
#  'summary_standard_decentralization__Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  'summary_standard_decentralization__Slovakia - SLO 2006 - SLO 2006 Direction.txt',
#  'summary_standard_lifestyle__Austria - AU 2019 - AU 2019 SDP.txt',
#  'summary_standard_lifestyle__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  'summary_standard_lifestyle__Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  'summary_standard_european_union__Austria - AU 2019 - AU 2019 SDP.txt',
#  'summary_standard_immigration__UK - UK 2019 Green.txt',
#  'summary_standard_immigration__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  'summary_standard_immigration__Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  'summary_standard_lifestyle__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt',
#  'summary_standard_european_union__Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  'summary_standard_environment__Austria - AU 2006 - AU 2006 FPO.txt',
#  'summary_standard_decentralization__Austria - AU 2019 - AU 2019 SDP.txt',
#  'summary_standard_european_union__Denmark - DEN 2019 SPP SF.txt',
#  'summary_standard_taxation__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  'summary_standard_environment__Slovakia - SLO 2006 - SLO 2006 Direction.txt',
#  'summary_standard_immigration__Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  'summary_standard_immigration__Netherlands - NL 2006 - NL 2006 VVD.txt',
#  'summary_standard_european_union__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  'summary_standard_european_union__UK - UK 2019 Green.txt',
#  'summary_standard_lifestyle__Bulgaria - BUL 2014 Attack.txt',
#  'summary_standard_immigration__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  'summary_standard_european_union__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  'summary_standard_taxation__Austria - AU 2006 - AU 2006 FPO.txt',
#  'summary_standard_immigration__Denmark - DEN 2019 SPP SF.txt',
#  'summary_standard_taxation__Sweden - SWE 2010 - SWE 2010 Moderate.txt',
#  'summary_standard_environment__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt',
#  'summary_standard_environment__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  'summary_standard_taxation__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt',
#  'summary_standard_european_union__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt',
#  'summary_standard_immigration__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt',
#  'summary_standard_lifestyle__Poland - POL 2019 Civic Coalition PO.txt',
#  'summary_standard_environment__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt',
#  'summary_standard_european_union__Slovakia - SLO 2006 - SLO 2006 Direction.txt',
#  'summary_standard_environment__Denmark - DEN 2019 SPP SF.txt',
#  'summary_standard_environment__Netherlands - NL 2010 - NL 2010 Green GL.txt',
#  'summary_standard_immigration__Slovakia - SLO 2006 - SLO 2006 Direction.txt']

# %%
# Should be 96 (16 files * 6 issues)
len(single_summaries)
# Out:
# 96

# %%
summary_meta_df = pd.DataFrame(single_summaries, columns=['filepath'])
summary_meta_df['file'] = summary_meta_df['filepath'].apply(lambda x: x.split('__')[1])
summary_meta_df['issue'] = summary_meta_df['filepath'].apply(lambda x: x.split('_')[2])
summary_meta_df
# Out:
#                                              filepath  \
# 0   summary_standard_immigration__Czech - CZ 2010 ...
# 1   summary_standard_european_union__Poland - POL ...
# 2   summary_standard_taxation__Belgium - BEL 2010 ...
# 3   summary_standard_environment__Belgium - BEL 20...
# 4   summary_standard_european_union__Austria - AU ...
# ..                                                ...
# 91  summary_standard_environment__Czech - CZ 2010 ...
# 92  summary_standard_european_union__Slovakia - SL...
# 93  summary_standard_environment__Denmark - DEN 20...
# 94  summary_standard_environment__Netherlands - NL...
# 95  summary_standard_immigration__Slovakia - SLO 2...
#
#                                              file        issue
# 0       Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt  immigration
# 1        Poland - POL 2019 Civic Coalition PO.txt     european
# 2   Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt     taxation
# 3   Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt  environment
# 4             Austria - AU 2006 - AU 2006 FPO.txt     european
# ..                                            ...          ...
# 91   Czech - CZ 2010 - CZ 2010 Communist KSCM.txt  environment
# 92   Slovakia - SLO 2006 - SLO 2006 Direction.txt     european
# 93                  Denmark - DEN 2019 SPP SF.txt  environment
# 94   Netherlands - NL 2010 - NL 2010 Green GL.txt  environment
# 95   Slovakia - SLO 2006 - SLO 2006 Direction.txt  immigration
#
# [96 rows x 3 columns]

# %%
grouped = summary_meta_df.groupby('file')
    
for file_name, group in grouped:
    combined_content = ""
    
    for _, row in group.iterrows():
        with open(os.path.join('../data/summaries/', row['filepath']), 'r') as file:
            combined_content += file.read() + "\n"
    
    output_file_path = os.path.join('../data/summaries/', 'summary_combined_multi_issue__' + file_name)  # specify your output directory
    with open(output_file_path, 'w') as output_file:
        output_file.write(combined_content)

# %%
# Should be 16
combined_summaries = [file for file in os.listdir('../data/summaries/') if (file.startswith('summary_combined'))]
len(combined_summaries)
# Out:
# 16

# %%
combined_results = []
# Loop through each file, issue area
for file_name in combined_summaries:
    print('Analyzing file: ', file_name)
    with open(os.path.join('../data/summaries/', file_name), 'r') as file:
        combined_summary = file.read()
    for issue in issue_list:
        print('-- Analyzing issue: ', issue)
        combined_issue_prompts = get_prompts(issue, combined_summary, override_persona_and_encouragement=(0,1))
        combined_issue_prompts_results = analyze_text_with_batch(combined_issue_prompts, model, parse_retries=3, max_retries=7, concurrency=9)
        results_df = pd.DataFrame(combined_issue_prompts_results)
        results_df['summary_style'] = 'combined'

        results_df['summary_length'] = 'combined'
        results_df['issue'] = issue
        results_df['model'] = model
        results_df['file'] = file_name
        results_df['created_at'] = datetime.now()
        results_df = results_df[[
            'file', 'issue', 'model', 'summary_style', 'summary_length', 'score', 'error_message', 'prompt', 'created_at']]

        # Writing to Excel as we go to avoid losing data in case of an error
        if os.path.exists(results_file):
            # Append to existing file
            with pd.ExcelWriter(results_file, mode='a', engine='openpyxl', if_sheet_exists='overlay') as writer:
                results_df.to_excel(
                    writer, index=False, header=False, sheet_name='Sheet1', startrow=writer.sheets['Sheet1'].max_row)
        else:
            # Create a new file
            with pd.ExcelWriter(results_file, mode='w', engine='openpyxl') as writer:
                results_df.to_excel(
                    writer, index=False, sheet_name='Sheet1')

        combined_results.append(results_df)
# Out:
# Analyzing file:  summary_combined_multi_issue__Finland - FIN 2019 - FIN 2019 Nat Coal KOK.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Bulgaria - BUL 2014 Attack.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Belgium - BEL 2014 - BEL 2014  New Flemish Alliance N VA.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Czech - CZ 2010 - CZ 2010 Civ Dem ODS.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Netherlands - NL 2006 - NL 2006 VVD.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Austria - AU 2019 - AU 2019 SDP.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Slovakia - SLO 2006 - SLO 2006 Direction.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__UK - UK 2019 Green.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Denmark - DEN 2019 SPP SF.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Czech - CZ 2010 - CZ 2010 Communist KSCM.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Sweden - SWE 2010 - SWE 2010 Moderate.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Netherlands - NL 2010 - NL 2010 Green GL.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Hungary - HUN 2014 - HUN 2010 Mvmnt for better Hungary JOBBIK.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Austria - AU 2006 - AU 2006 FPO.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Belgium - BEL 2010 - BEL 2010 Green Ecolo.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization
# Analyzing file:  summary_combined_multi_issue__Poland - POL 2019 Civic Coalition PO.txt
# -- Analyzing issue:  european_union
# -- Analyzing issue:  taxation
# -- Analyzing issue:  lifestyle
# -- Analyzing issue:  immigration
# -- Analyzing issue:  environment
# -- Analyzing issue:  decentralization

# %%
final_df = pd.concat(combined_results, axis=0)
final_df = final_df.reset_index(drop=True)

# %%
final_df
# Out:
#                                                  file             issue  \
# 0   summary_combined_multi_issue__Finland - FIN 20...    european_union
# 1   summary_combined_multi_issue__Finland - FIN 20...          taxation
# 2   summary_combined_multi_issue__Finland - FIN 20...         lifestyle
# 3   summary_combined_multi_issue__Finland - FIN 20...       immigration
# 4   summary_combined_multi_issue__Finland - FIN 20...       environment
# ..                                                ...               ...
# 91  summary_combined_multi_issue__Poland - POL 201...          taxation
# 92  summary_combined_multi_issue__Poland - POL 201...         lifestyle
# 93  summary_combined_multi_issue__Poland - POL 201...       immigration
# 94  summary_combined_multi_issue__Poland - POL 201...       environment
# 95  summary_combined_multi_issue__Poland - POL 201...  decentralization
#
#      model summary_style summary_length score error_message  \
# 0   gpt-4o      combined       combined     1          None
# 1   gpt-4o      combined       combined     4          None
# 2   gpt-4o      combined       combined    NA          None
# 3   gpt-4o      combined       combined     4          None
# 4   gpt-4o      combined       combined     2          None
# ..     ...           ...            ...   ...           ...
# 91  gpt-4o      combined       combined     3          None
# 92  gpt-4o      combined       combined     2          None
# 93  gpt-4o      combined       combined    NA          None
# 94  gpt-4o      combined       combined     1          None
# 95  gpt-4o      combined       combined     1          None
#
#                                                prompt  \
# 0   [content="You are an expert social scientist w...
# 1   [content='You are an expert social scientist w...
# 2   [content='You are an expert social scientist w...
# 3   [content='You are an expert social scientist w...
# 4   [content='You are an expert social scientist w...
# ..                                                ...
# 91  [content='You are an expert social scientist w...
# 92  [content='You are an expert social scientist w...
# 93  [content='You are an expert social scientist w...
# 94  [content='You are an expert social scientist w...
# 95  [content='You are an expert social scientist w...
#
#                    created_at
# 0  2024-08-01 11:45:28.670996
# 1  2024-08-01 11:45:29.510242
# 2  2024-08-01 11:45:30.503141
# 3  2024-08-01 11:45:31.219595
# 4  2024-08-01 11:45:31.965288
# ..                        ...
# 91 2024-08-01 11:46:55.903241
# 92 2024-08-01 11:46:56.621226
# 93 2024-08-01 11:46:57.541909
# 94 2024-08-01 11:46:58.358244
# 95 2024-08-01 11:46:59.078264
#
# [96 rows x 9 columns]
