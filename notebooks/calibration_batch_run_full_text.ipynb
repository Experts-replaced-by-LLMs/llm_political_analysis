# %%
import os
from llm_political_analysis.modules.analyze import bulk_analyze_text

# %%
filelist = os.listdir('../data/plaintext/')
calibration_files = ['../data/plaintext/'+file for file in filelist if 'Calibration' in file]
model_list = ['gpt-4o', 'gemini-1.5-pro-001', 'claude-3-5-sonnet-20240620']
issue_list = ['european_union', 'taxation', 'lifestyle', 'immigration', 'environment', 'decentralization']

# %% [markdown]
# ### Note below is an attempted run without summarization. I cancelled the run after a Claude analyzing a single issue on the German CDU-CSU manifesto consumed ~1 million tokens on one set of 9 prompts. I observed the token used via the Claude console.

# %%
results = bulk_analyze_text(calibration_files, model_list, issue_list, results_file='../data/results/calibration_results_full_text.xlsx', summarize=False, concurrency=1)
# Out:
# Analyzing file:  ../data/plaintext/0 Calibration - HUN 2010 Soc Dem.txt
# -- Analyzing issue:  european_union
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gemini-1.5-pro-001
# ---- Analyzing with model:  claude-3-5-sonnet-20240620
# -- Analyzing issue:  taxation
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gemini-1.5-pro-001
# ---- Analyzing with model:  claude-3-5-sonnet-20240620
# -- Analyzing issue:  lifestyle
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gemini-1.5-pro-001
# ---- Analyzing with model:  claude-3-5-sonnet-20240620
# -- Analyzing issue:  immigration
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gemini-1.5-pro-001
# ---- Analyzing with model:  claude-3-5-sonnet-20240620
# -- Analyzing issue:  environment
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gemini-1.5-pro-001
# ---- Analyzing with model:  claude-3-5-sonnet-20240620
# ...

# %%
results
