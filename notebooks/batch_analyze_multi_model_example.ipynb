# %%
from llm_political_analysis.modules.analyze import batch_analyze_text

# %%
file_list = ['../data/plaintext/0 Calibration - HUN 2010 Soc Dem.txt']
model_list = ['gpt-4o', 'gemini-1.5-pro-001', 'claude-3-5-sonnet-20240620']
issue_list = ['taxation']

# %%
results = batch_analyze_text(file_list, model_list, issue_list)
# Out:
# Analyzing file:  ../data/plaintext/0 Calibration - HUN 2010 Soc Dem.txt
# -- Analyzing issue:  taxation
# Summarized so far: 1 out of 1 chunks
# Final summary length: 1453 characters
#
# ---- Analyzing with model:  gpt-4o
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gemini-1.5-pro-001
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  claude-3-5-sonnet-20240620
# ------ Analyzing with prompt: 9 out of 9

# %%
results
# Out:
#                                                  file     issue  \
# 0   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 1   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 2   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 3   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 4   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 5   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 6   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 7   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 8   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 9   ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 10  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 11  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 12  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 13  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 14  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 15  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 16  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 17  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 18  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 19  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 20  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 21  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 22  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 23  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 24  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 25  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
# 26  ../data/plaintext/0 Calibration - HUN 2010 Soc...  taxation
#
#                          model score error_message  \
# 0                       gpt-4o     1          None
# 1                       gpt-4o     1          None
# 2                       gpt-4o     1          None
# 3                       gpt-4o     1          None
# 4                       gpt-4o     1          None
# 5                       gpt-4o     1          None
# 6                       gpt-4o     1          None
# 7                       gpt-4o     1          None
# 8                       gpt-4o     1          None
# 9           gemini-1.5-pro-001     3          None
# 10          gemini-1.5-pro-001     2          None
# 11          gemini-1.5-pro-001     2          None
# 12          gemini-1.5-pro-001     2          None
# 13          gemini-1.5-pro-001     2          None
# 14          gemini-1.5-pro-001     3          None
# 15          gemini-1.5-pro-001     3          None
# 16          gemini-1.5-pro-001     3          None
# 17          gemini-1.5-pro-001     3          None
# 18  claude-3-5-sonnet-20240620     3          None
# 19  claude-3-5-sonnet-20240620     3          None
# 20  claude-3-5-sonnet-20240620     3          None
# 21  claude-3-5-sonnet-20240620     3          None
# 22  claude-3-5-sonnet-20240620     3          None
# 23  claude-3-5-sonnet-20240620     3          None
# 24  claude-3-5-sonnet-20240620     3          None
# 25  claude-3-5-sonnet-20240620     3          None
# 26  claude-3-5-sonnet-20240620     3          None
#
#                                                prompt
# 0   [{'role': 'system', 'content': 'You are an exp...
# 1   [{'role': 'system', 'content': 'You are an exp...
# 2   [{'role': 'system', 'content': 'You are an exp...
# 3   [{'role': 'system', 'content': 'You are highly...
# 4   [{'role': 'system', 'content': 'You are highly...
# 5   [{'role': 'system', 'content': 'You are highly...
# 6   [{'role': 'system', 'content': 'You are a prof...
# 7   [{'role': 'system', 'content': 'You are a prof...
# 8   [{'role': 'system', 'content': 'You are a prof...
# 9   [{'role': 'system', 'content': 'You are an exp...
# 10  [{'role': 'system', 'content': 'You are an exp...
# 11  [{'role': 'system', 'content': 'You are an exp...
# 12  [{'role': 'system', 'content': 'You are highly...
# 13  [{'role': 'system', 'content': 'You are highly...
# 14  [{'role': 'system', 'content': 'You are highly...
# 15  [{'role': 'system', 'content': 'You are a prof...
# 16  [{'role': 'system', 'content': 'You are a prof...
# 17  [{'role': 'system', 'content': 'You are a prof...
# 18  [{'role': 'system', 'content': 'You are an exp...
# 19  [{'role': 'system', 'content': 'You are an exp...
# 20  [{'role': 'system', 'content': 'You are an exp...
# 21  [{'role': 'system', 'content': 'You are highly...
# 22  [{'role': 'system', 'content': 'You are highly...
# 23  [{'role': 'system', 'content': 'You are highly...
# 24  [{'role': 'system', 'content': 'You are a prof...
# 25  [{'role': 'system', 'content': 'You are a prof...
# 26  [{'role': 'system', 'content': 'You are a prof...

# %%
results.to_excel('../data/results/manifesto_multimodel_analysis_results.xlsx', index=False)
