# %%
from llm_political_analysis.modules.analyze import batch_analyze_text

# %%
file_list = ['../data/plaintext/0 Calibration - HUN 2010 Soc Dem.txt',
             '../data/plaintext/0 Calibration - IRL 1989 Lab txt.txt']

model_list = ['gpt-4o', 'gpt-4', 'gpt-3.5-turbo']

issue_list = ['taxation', 'lifestyle']

# %%
results = batch_analyze_text(file_list, model_list, issue_list)
# Out:
# Analyzing file:  ../data/plaintext/0 Calibration - HUN 2010 Soc Dem.txt
# -- Analyzing issue:  taxation
# Summarized so far: 1 out of 1 chunks
#
# ---- Analyzing with model:  gpt-4o
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-4
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-3.5-turbo
# ------ Analyzing with prompt: 9 out of 9
#
# -- Analyzing issue:  lifestyle
# Summarized so far: 1 out of 1 chunks
#
# ---- Analyzing with model:  gpt-4o
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-4
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-3.5-turbo
# ------ Analyzing with prompt: 9 out of 9
#
# Analyzing file:  ../data/plaintext/0 Calibration - IRL 1989 Lab txt.txt
# -- Analyzing issue:  taxation
# Summarized so far: 6 out of 6 chunks
#
# Condensing final summary since it is 5570 characters
# ---- Analyzing with model:  gpt-4o
# ------ Analyzing with prompt: 9 out of 9  retrying attempt 2
#
# ---- Analyzing with model:  gpt-4
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-3.5-turbo
# ------ Analyzing with prompt: 9 out of 9
#
# -- Analyzing issue:  lifestyle
# Summarized so far: 6 out of 6 chunks
#
# ---- Analyzing with model:  gpt-4o
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-4
# ------ Analyzing with prompt: 9 out of 9
#
# ---- Analyzing with model:  gpt-3.5-turbo
# ------ Analyzing with prompt: 9 out of 9

# %%
results
# Out:
#                                                   file      issue  \
# 0    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 1    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 2    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 3    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 4    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# ..                                                 ...        ...
# 103  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 104  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 105  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 106  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 107  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
#
#              model score                                        explanation  \
# 0           gpt-4o     2  The manifesto strongly emphasizes increasing s...
# 1           gpt-4o     2  The manifesto strongly favors increasing publi...
# 2           gpt-4o     2  The manifesto emphasizes significant increases...
# 3           gpt-4o     2  The manifesto strongly favors increasing publi...
# 4           gpt-4o     2  The manifesto emphasizes significant increases...
# ..             ...   ...                                                ...
# 103  gpt-3.5-turbo     1  The party strongly supports liberal social pol...
# 104  gpt-3.5-turbo     1  The party strongly supports liberal social pol...
# 105  gpt-3.5-turbo     1  The party strongly supports liberal social pol...
# 106  gpt-3.5-turbo     1  The party strongly supports liberal social pol...
# 107  gpt-3.5-turbo     1  The party strongly supports liberal social pol...
#
#                                                 prompt
# 0    [{'role': 'system', 'content': 'You are an exp...
# 1    [{'role': 'system', 'content': 'You are an exp...
# 2    [{'role': 'system', 'content': 'You are an exp...
# 3    [{'role': 'system', 'content': 'You are highly...
# 4    [{'role': 'system', 'content': 'You are highly...
# ..                                                 ...
# 103  [{'role': 'system', 'content': 'You are highly...
# 104  [{'role': 'system', 'content': 'You are highly...
# 105  [{'role': 'system', 'content': 'You are a prof...
# 106  [{'role': 'system', 'content': 'You are a prof...
# 107  [{'role': 'system', 'content': 'You are a prof...
#
# [108 rows x 6 columns]

# %%
results.to_excel('manifesto_analysis_results.xlsx', index=False)
