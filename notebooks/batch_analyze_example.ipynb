# %%
from llm_political_analysis.modules.analyze import bulk_analyze_text

# %%
file_list = ['../data/plaintext/0 Calibration - IRL 1989 Lab txt.txt']

model_list = ['gpt-4o', 'gpt-4', 'gpt-3.5-turbo']

issue_list = ['taxation', 'lifestyle']

# %%
results = bulk_analyze_text(file_list, model_list, issue_list)
# Out:
# Analyzing file:  ../data/plaintext/0 Calibration - IRL 1989 Lab txt.txt
# -- Analyzing issue:  taxation
# Summarized so far: 6 out of 6 chunks
# Condensing final summary since it is 5588 characters
# Final summary length: 5562 characters
#
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gpt-4
# ---- Analyzing with model:  gpt-3.5-turbo
# -- Analyzing issue:  lifestyle
# Summarized so far: 6 out of 6 chunks
# Condensing final summary since it is 5013 characters
# Final summary length: 4910 characters
#
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gpt-4
# ---- Analyzing with model:  gpt-3.5-turbo

# %%
results
# Out:
#    score error_message                                             prompt  \
# 0      1          None  [content='\n    You are an expert social scien...
# 1      1          None  [content='\n    You are an expert social scien...
# 2      1          None  [content='\n    You are an expert social scien...
# 3      1          None  [content='\n    You are highly intelligent.  T...
# 4      1          None  [content='\n    You are highly intelligent.  T...
# 5      1          None  [content='\n    You are highly intelligent.  I...
# 6      1          None  [content='\n    You are a professor of economi...
# 7      1          None  [content='\n    You are a professor of economi...
# 8      1          None  [content='\n    You are a professor of economi...
# 9      2          None  [content='\n    You are an expert social scien...
# 10     2          None  [content='\n    You are an expert social scien...
# 11     2          None  [content='\n    You are an expert social scien...
# ...

# %%
results.to_excel('../data/results/manifesto_batch_analysis_results.xlsx', index=False)
