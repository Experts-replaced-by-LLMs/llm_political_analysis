# %%
from llm_political_analysis.modules.analyze import bulk_analyze_text

# %%
file_list = ['../data/plaintext/0 Calibration - IRL 1989 Lab txt.txt']

model_list = ['gpt-4o', 'gpt-4', 'gpt-3.5-turbo']

issue_list = ['taxation', 'lifestyle']

# %%
results = bulk_analyze_text(file_list, model_list, issue_list)
# Out:
# Analyzing file:  ../data/plaintext/0 Calibration - HUN 2010 Soc Dem.txt
# -- Analyzing issue:  taxation
# Summarized so far: 1 out of 1 chunks
# Final summary length: 1453 characters
#
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gpt-4
# ---- Analyzing with model:  gpt-3.5-turbo
# -- Analyzing issue:  lifestyle
# Summarized so far: 1 out of 1 chunks
# Final summary length: 2380 characters
#
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gpt-4
# ---- Analyzing with model:  gpt-3.5-turbo
# Analyzing file:  ../data/plaintext/0 Calibration - IRL 1989 Lab txt.txt
# -- Analyzing issue:  taxation
# Summarized so far: 6 out of 6 chunks
# Final summary length: 3842 characters
#
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gpt-4
# ---- Analyzing with model:  gpt-3.5-turbo
# -- Analyzing issue:  lifestyle
# Summarized so far: 6 out of 6 chunks
# Final summary length: 4803 characters
#
# ---- Analyzing with model:  gpt-4o
# ---- Analyzing with model:  gpt-4
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = bulk_analyze_text(file_list, model_list, issue_list)
#
# File ~/repos/llm_political_analysis/modules/analyze.py:202, in bulk_analyze_text(file_list, model_list, issue_list, probabilities, summary_model)
#     199 for model in model_list:
#     200     print('---- Analyzing with model: ', model)
# --> 202     results = analyze_text_with_batch(prompts, model, parse_retries=3)
#     203     results_df = pd.DataFrame(results)
#     204     results_df['issue'] = issue
#
# File ~/repos/llm_political_analysis/modules/analyze.py:141, in analyze_text_with_batch(prompt_list, model, parse_retries, max_retries)
#     138     print(f"Please select from the following models: {openai_model_list + claude_model_list + gemini_model_list}")
#     140 # This is the core call to the model
# --> 141 responses = llm.batch(prompt_list)
#     144 # This is hardcoded to expect a single score or NA in the response
#     145 # If the desired response changes this will need to be updated
#     146 # Originally this handled a json response but that was removed to make
#     147 # this more robust.
#     148 response_dicts = []
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/runnables/base.py:642, in Runnable.batch(self, inputs, config, return_exceptions, **kwargs)
#     639     return cast(List[Output], [invoke(inputs[0], configs[0])])
#     641 with get_executor_for_config(configs[0]) as executor:
# --> 642     return cast(List[Output], list(executor.map(invoke, inputs, configs)))
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/runnables/config.py:499, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     498 def _wrapped_fn(*args: Any) -> T:
# --> 499     return contexts.pop().run(fn, *args)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/runnables/base.py:635, in Runnable.batch.<locals>.invoke(input, config)
#     633         return e
#     634 else:
# --> 635     return self.invoke(input, config, **kwargs)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:248, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     237 def invoke(
#     238     self,
#     239     input: LanguageModelInput,
#    (...)
#     243     **kwargs: Any,
#     244 ) -> BaseMessage:
#     245     config = ensure_config(config)
#     246     return cast(
#     247         ChatGeneration,
# --> 248         self.generate_prompt(
#     249             [self._convert_input(input)],
#     250             stop=stop,
#     251             callbacks=config.get("callbacks"),
#     252             tags=config.get("tags"),
#     253             metadata=config.get("metadata"),
#     254             run_name=config.get("run_name"),
#     255             run_id=config.pop("run_id", None),
#     256             **kwargs,
#     257         ).generations[0][0],
#     258     ).message
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:677, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     669 def generate_prompt(
#     670     self,
#     671     prompts: List[PromptValue],
#    (...)
#     674     **kwargs: Any,
#     675 ) -> LLMResult:
#     676     prompt_messages = [p.to_messages() for p in prompts]
# --> 677     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:534, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     532         if run_managers:
#     533             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 534         raise e
#     535 flattened_outputs = [
#     536     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     537     for res in results
#     538 ]
#     539 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:524, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     521 for i, m in enumerate(messages):
#     522     try:
#     523         results.append(
# --> 524             self._generate_with_cache(
#     525                 m,
#     526                 stop=stop,
#     527                 run_manager=run_managers[i] if run_managers else None,
#     528                 **kwargs,
#     529             )
#     530         )
#     531     except BaseException as e:
#     532         if run_managers:
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:749, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     747 else:
#     748     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 749         result = self._generate(
#     750             messages, stop=stop, run_manager=run_manager, **kwargs
#     751         )
#     752     else:
#     753         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:543, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     541 message_dicts, params = self._create_message_dicts(messages, stop)
#     542 params = {**params, **kwargs}
# --> 543 response = self.client.create(messages=message_dicts, **params)
#     544 return self._create_chat_result(response)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     609 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     610 def create(
#     611     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "parallel_tool_calls": parallel_tool_calls,
#     657                 "presence_penalty": presence_penalty,
#     658                 "response_format": response_format,
#     659                 "seed": seed,
#     660                 "service_tier": service_tier,
#     661                 "stop": stop,
#     662                 "stream": stream,
#     663                 "stream_options": stream_options,
#     664                 "temperature": temperature,
#     665                 "tool_choice": tool_choice,
#     666                 "tools": tools,
#     667                 "top_logprobs": top_logprobs,
#     668                 "top_p": top_p,
#     669                 "user": user,
#     670             },
#     671             completion_create_params.CompletionCreateParams,
#     672         ),
#     673         options=make_request_options(
#     674             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     675         ),
#     676         cast_to=ChatCompletion,
#     677         stream=stream or False,
#     678         stream_cls=Stream[ChatCompletionChunk],
#     679     )
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1250, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1236 def post(
#    1237     self,
#    1238     path: str,
#    (...)
#    1245     stream_cls: type[_StreamT] | None = None,
#    1246 ) -> ResponseT | _StreamT:
#    1247     opts = FinalRequestOptions.construct(
#    1248         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1249     )
# -> 1250     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:931, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     922 def request(
#     923     self,
#     924     cast_to: Type[ResponseT],
#    (...)
#     929     stream_cls: type[_StreamT] | None = None,
#     930 ) -> ResponseT | _StreamT:
# --> 931     return self._request(
#     932         cast_to=cast_to,
#     933         options=options,
#     934         stream=stream,
#     935         stream_cls=stream_cls,
#     936         remaining_retries=remaining_retries,
#     937     )
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1015, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1013 if retries > 0 and self._should_retry(err.response):
#    1014     err.response.close()
# -> 1015     return self._retry_request(
#    1016         options,
#    1017         cast_to,
#    1018         retries,
#    1019         err.response.headers,
#    1020         stream=stream,
#    1021         stream_cls=stream_cls,
#    1022     )
#    1024 # If the response is streamed then we need to explicitly read the response
#    1025 # to completion before attempting to access the response text.
#    1026 if not err.response.is_closed:
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1063, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1059 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1060 # different thread if necessary.
#    1061 time.sleep(timeout)
# -> 1063 return self._request(
#    1064     options=options,
#    1065     cast_to=cast_to,
#    1066     remaining_retries=remaining,
#    1067     stream=stream,
#    1068     stream_cls=stream_cls,
#    1069 )
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1015, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1013 if retries > 0 and self._should_retry(err.response):
#    1014     err.response.close()
# -> 1015     return self._retry_request(
#    1016         options,
#    1017         cast_to,
#    1018         retries,
#    1019         err.response.headers,
#    1020         stream=stream,
#    1021         stream_cls=stream_cls,
#    1022     )
#    1024 # If the response is streamed then we need to explicitly read the response
#    1025 # to completion before attempting to access the response text.
#    1026 if not err.response.is_closed:
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1063, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1059 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1060 # different thread if necessary.
#    1061 time.sleep(timeout)
# -> 1063 return self._request(
#    1064     options=options,
#    1065     cast_to=cast_to,
#    1066     remaining_retries=remaining,
#    1067     stream=stream,
#    1068     stream_cls=stream_cls,
#    1069 )
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1015, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1013 if retries > 0 and self._should_retry(err.response):
#    1014     err.response.close()
# -> 1015     return self._retry_request(
#    1016         options,
#    1017         cast_to,
#    1018         retries,
#    1019         err.response.headers,
#    1020         stream=stream,
#    1021         stream_cls=stream_cls,
#    1022     )
#    1024 # If the response is streamed then we need to explicitly read the response
#    1025 # to completion before attempting to access the response text.
#    1026 if not err.response.is_closed:
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1063, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1059 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1060 # different thread if necessary.
#    1061 time.sleep(timeout)
# -> 1063 return self._request(
#    1064     options=options,
#    1065     cast_to=cast_to,
#    1066     remaining_retries=remaining,
#    1067     stream=stream,
#    1068     stream_cls=stream_cls,
#    1069 )
#
# File ~/miniconda3/envs/llm_poli/lib/python3.11/site-packages/openai/_base_client.py:1030, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1027         err.response.read()
#    1029     log.debug("Re-raising status error")
# -> 1030     raise self._make_status_error_from_response(err.response) from None
#    1032 return self._process_response(
#    1033     cast_to=cast_to,
#    1034     options=options,
#    (...)
#    1037     stream_cls=stream_cls,
#    1038 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-pTy1FhaWr1IJKEIqKgz4HKrh on tokens per min (TPM): Limit 10000, Used 8898, Requested 1657. Please try again in 3.33s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
results
# Out:
#                                                   file      issue  \
# 0    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 1    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 2    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 3    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# 4    ../data/plaintext/0 Calibration - HUN 2010 Soc...   taxation
# ..                                                 ...        ...
# 103  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 104  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 105  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 106  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
# 107  ../data/plaintext/0 Calibration - IRL 1989 Lab...  lifestyle
#
#              model score error_message  \
# 0           gpt-4o     1          None
# 1           gpt-4o     1          None
# 2           gpt-4o     1          None
# 3           gpt-4o     1          None
# 4           gpt-4o     1          None
# ..             ...   ...           ...
# 103  gpt-3.5-turbo     3          None
# 104  gpt-3.5-turbo     2          None
# 105  gpt-3.5-turbo     2          None
# 106  gpt-3.5-turbo     3          None
# 107  gpt-3.5-turbo     2          None
#
#                                                 prompt
# 0    [{'role': 'system', 'content': 'You are an exp...
# 1    [{'role': 'system', 'content': 'You are an exp...
# 2    [{'role': 'system', 'content': 'You are an exp...
# 3    [{'role': 'system', 'content': 'You are highly...
# 4    [{'role': 'system', 'content': 'You are highly...
# ..                                                 ...
# 103  [{'role': 'system', 'content': 'You are highly...
# 104  [{'role': 'system', 'content': 'You are highly...
# 105  [{'role': 'system', 'content': 'You are a prof...
# 106  [{'role': 'system', 'content': 'You are a prof...
# 107  [{'role': 'system', 'content': 'You are a prof...
#
# [108 rows x 6 columns]

# %%
results.to_excel('../data/results/manifesto_batch_analysis_results.xlsx', index=False)
